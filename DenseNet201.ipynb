# %% [markdown]
# # Data Importing

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt
import numpy as np
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing import image
import os
from sklearn.model_selection import train_test_split
from sklearn import svm
from sklearn import metrics
from skimage import io, transform
from sklearn.model_selection import learning_curve
import matplotlib.pyplot as plt
from keras.callbacks import ModelCheckpoint, EarlyStopping,CSVLogger,ProgbarLogger
from keras.layers import Dense, Dropout, Activation, Flatten, GlobalAveragePooling2D, BatchNormalization
from keras.regularizers import l2

# %%
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# **Changable_Parameter**

# %%
#here image size is 256x256
IMAGE_SIZE = 200
#every time process 32 images (61x31)~1951
batch_size = 10
#how many color have in these pictures
CHANNELS = 3
#80x25~1951
EPOCHS = 25
NUM_CLASSES = 8
input_shape = (batch_size, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)
patience=5
data_dir ="E:\\ICCIT\\mango\\MangoLeafBD Dataset\\MangoLeafBD Dataset"
split_folder = "E:\\ICCIT\\mango\\split"
model_name="densenet201"

# %% [markdown]
# **Directory Creation and split**

# %%
import os
import shutil
import random
import math

# Example paths

train_val_dir = os.path.join(split_folder, "train_validation_data")
test_dir = os.path.join(split_folder, "test_data")

def split_data(source_folder, split_folder, train_val_ratio=0.9):
    # Check if split folders already exist
    if os.path.exists(train_val_dir) and os.path.exists(test_dir):
        print("Split folders already exist. Skipping data split.")
        return
    
    # Create split folders if they do not exist
    if not os.path.exists(split_folder):
        os.makedirs(split_folder)
    if not os.path.exists(train_val_dir):
        os.makedirs(train_val_dir)
    if not os.path.exists(test_dir):
        os.makedirs(test_dir)
    
    # Count variables
    train_val_count = 0
    test_count = 0
    
    for class_folder in os.listdir(source_folder):
        class_path = os.path.join(source_folder, class_folder)
        
        if os.path.isdir(class_path):
            train_val_class_path = os.path.join(train_val_dir, class_folder)
            test_class_path = os.path.join(test_dir, class_folder)
            
            if not os.path.exists(train_val_class_path):
                os.makedirs(train_val_class_path)
            if not os.path.exists(test_class_path):
                os.makedirs(test_class_path)
            
            images = [img for img in os.listdir(class_path) if img.endswith('.jpg') or img.endswith('.png')]
            random.shuffle(images)
            
            # Calculate split indices
            split_index = int(len(images) * train_val_ratio)
            
            # Split images into train_validation_data and test_data
            train_val_images = images[:split_index]
            test_images = images[split_index:]
            
            # Copy images to respective split folders
            for img in train_val_images:
                src = os.path.join(class_path, img)
                dst = os.path.join(train_val_class_path, img)
                shutil.copy(src, dst)
                train_val_count += 1
                
            for img in test_images:
                src = os.path.join(class_path, img)
                dst = os.path.join(test_class_path, img)
                shutil.copy(src, dst)
                test_count += 1
    
    print("Data split completed successfully.")
    print(f"Number of images in train_validation_data: {train_val_count}")
    print(f"Number of images in test_data: {test_count}")
    print(f"Total number of images: {train_val_count + test_count}")

# Call the function with your paths
split_data(data_dir, split_folder)
# Out:
# Data split completed successfully.
# Number of images in train_validation_data: 3600
# Number of images in test_data: 400
# Total number of images: 4000

# %%
import os
import shutil
import random
import tensorflow as tf

# data augmentation parameters
datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,
    validation_split=0.10+.03,  # 10% of the data will be used for validation
)

train_generator = datagen.flow_from_directory(
    train_val_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical', 
    subset='training' 
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)


validation_generator = datagen.flow_from_directory(
    train_val_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical',  
    subset='validation'  

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_directory(
    test_dir,
    target_size=(IMAGE_SIZE, IMAGE_SIZE),
    batch_size=batch_size,
    class_mode='categorical'  # Update for multi-class classification
)
# Out:
# Found 3136 images belonging to 8 classes.
# Found 464 images belonging to 8 classes.
# Found 400 images belonging to 8 classes.

# %%
images, labels = next(train_generator)
fig, axes = plt.subplots(1, 4, figsize=(15, 5))
for i in range(4):
    random_index = np.random.randint(0, batch_size)
    
    axes[i].imshow(images[random_index])
    label = labels[random_index]
    class_name = train_generator.class_indices
    axes[i].set_title(list(class_name.keys())[np.argmax(label)])

plt.show()

# %% [markdown]
# # Building model

# %%
from tensorflow.keras.applications import EfficientNetV2B0,ResNet50,InceptionV3,NASNetMobile,EfficientNetV2L,DenseNet201

model= DenseNet201(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (IMAGE_SIZE, IMAGE_SIZE, 3)
                 )
for layer in model.layers:
    layer.trainable = False
    
# Let's print our layers 
for (i,layer) in enumerate(model.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 ZeroPadding2D False
# 2 Conv2D False
# 3 BatchNormalization False
# 4 Activation False
# 5 ZeroPadding2D False
# 6 MaxPooling2D False
# 7 BatchNormalization False
# 8 Activation False
# 9 Conv2D False
# 10 BatchNormalization False
# 11 Activation False
# 12 Conv2D False
# 13 Concatenate False
# 14 BatchNormalization False
# 15 Activation False
# 16 Conv2D False
# 17 BatchNormalization False
# 18 Activation False
# 19 Conv2D False
# 20 Concatenate False
# 21 BatchNormalization False
# 22 Activation False
# 23 Conv2D False
# 24 BatchNormalization False
# 25 Activation False
# 26 Conv2D False
# 27 Concatenate False
# 28 BatchNormalization False
# 29 Activation False
# 30 Conv2D False
# 31 BatchNormalization False
# 32 Activation False
# 33 Conv2D False
# 34 Concatenate False
# 35 BatchNormalization False
# 36 Activation False
# 37 Conv2D False
# 38 BatchNormalization False
# 39 Activation False
# 40 Conv2D False
# 41 Concatenate False
# 42 BatchNormalization False
# 43 Activation False
# 44 Conv2D False
# 45 BatchNormalization False
# 46 Activation False
# 47 Conv2D False
# 48 Concatenate False
# 49 BatchNormalization False
# 50 Activation False
# 51 Conv2D False
# 52 AveragePooling2D False
# 53 BatchNormalization False
# 54 Activation False
# 55 Conv2D False
# 56 BatchNormalization False
# 57 Activation False
# 58 Conv2D False
# 59 Concatenate False
# 60 BatchNormalization False
# 61 Activation False
# 62 Conv2D False
# 63 BatchNormalization False
# 64 Activation False
# 65 Conv2D False
# 66 Concatenate False
# 67 BatchNormalization False
# 68 Activation False
# 69 Conv2D False
# 70 BatchNormalization False
# 71 Activation False
# 72 Conv2D False
# 73 Concatenate False
# 74 BatchNormalization False
# 75 Activation False
# 76 Conv2D False
# 77 BatchNormalization False
# 78 Activation False
# 79 Conv2D False
# 80 Concatenate False
# 81 BatchNormalization False
# 82 Activation False
# 83 Conv2D False
# 84 BatchNormalization False
# 85 Activation False
# 86 Conv2D False
# 87 Concatenate False
# 88 BatchNormalization False
# 89 Activation False
# 90 Conv2D False
# 91 BatchNormalization False
# 92 Activation False
# 93 Conv2D False
# 94 Concatenate False
# 95 BatchNormalization False
# 96 Activation False
# 97 Conv2D False
# 98 BatchNormalization False
# 99 Activation False
# 100 Conv2D False
# 101 Concatenate False
# 102 BatchNormalization False
# 103 Activation False
# 104 Conv2D False
# 105 BatchNormalization False
# 106 Activation False
# 107 Conv2D False
# 108 Concatenate False
# 109 BatchNormalization False
# 110 Activation False
# 111 Conv2D False
# 112 BatchNormalization False
# 113 Activation False
# 114 Conv2D False
# 115 Concatenate False
# 116 BatchNormalization False
# 117 Activation False
# 118 Conv2D False
# 119 BatchNormalization False
# 120 Activation False
# 121 Conv2D False
# 122 Concatenate False
# 123 BatchNormalization False
# 124 Activation False
# 125 Conv2D False
# 126 BatchNormalization False
# 127 Activation False
# 128 Conv2D False
# 129 Concatenate False
# 130 BatchNormalization False
# 131 Activation False
# 132 Conv2D False
# 133 BatchNormalization False
# 134 Activation False
# 135 Conv2D False
# 136 Concatenate False
# 137 BatchNormalization False
# 138 Activation False
# 139 Conv2D False
# 140 AveragePooling2D False
# 141 BatchNormalization False
# 142 Activation False
# 143 Conv2D False
# 144 BatchNormalization False
# 145 Activation False
# 146 Conv2D False
# 147 Concatenate False
# 148 BatchNormalization False
# 149 Activation False
# 150 Conv2D False
# 151 BatchNormalization False
# 152 Activation False
# 153 Conv2D False
# 154 Concatenate False
# 155 BatchNormalization False
# 156 Activation False
# 157 Conv2D False
# 158 BatchNormalization False
# 159 Activation False
# 160 Conv2D False
# 161 Concatenate False
# 162 BatchNormalization False
# 163 Activation False
# 164 Conv2D False
# 165 BatchNormalization False
# 166 Activation False
# 167 Conv2D False
# 168 Concatenate False
# 169 BatchNormalization False
# 170 Activation False
# 171 Conv2D False
# 172 BatchNormalization False
# 173 Activation False
# 174 Conv2D False
# 175 Concatenate False
# 176 BatchNormalization False
# 177 Activation False
# 178 Conv2D False
# 179 BatchNormalization False
# 180 Activation False
# 181 Conv2D False
# 182 Concatenate False
# 183 BatchNormalization False
# 184 Activation False
# 185 Conv2D False
# 186 BatchNormalization False
# 187 Activation False
# 188 Conv2D False
# 189 Concatenate False
# 190 BatchNormalization False
# 191 Activation False
# 192 Conv2D False
# 193 BatchNormalization False
# 194 Activation False
# 195 Conv2D False
# 196 Concatenate False
# 197 BatchNormalization False
# 198 Activation False
# 199 Conv2D False
# 200 BatchNormalization False
# 201 Activation False
# 202 Conv2D False
# 203 Concatenate False
# 204 BatchNormalization False
# 205 Activation False
# 206 Conv2D False
# 207 BatchNormalization False
# 208 Activation False
# 209 Conv2D False
# 210 Concatenate False
# 211 BatchNormalization False
# 212 Activation False
# 213 Conv2D False
# 214 BatchNormalization False
# 215 Activation False
# 216 Conv2D False
# 217 Concatenate False
# 218 BatchNormalization False
# 219 Activation False
# 220 Conv2D False
# 221 BatchNormalization False
# 222 Activation False
# 223 Conv2D False
# 224 Concatenate False
# 225 BatchNormalization False
# 226 Activation False
# 227 Conv2D False
# 228 BatchNormalization False
# 229 Activation False
# 230 Conv2D False
# 231 Concatenate False
# 232 BatchNormalization False
# 233 Activation False
# 234 Conv2D False
# 235 BatchNormalization False
# 236 Activation False
# 237 Conv2D False
# 238 Concatenate False
# 239 BatchNormalization False
# 240 Activation False
# 241 Conv2D False
# 242 BatchNormalization False
# 243 Activation False
# 244 Conv2D False
# 245 Concatenate False
# 246 BatchNormalization False
# 247 Activation False
# 248 Conv2D False
# 249 BatchNormalization False
# 250 Activation False
# 251 Conv2D False
# 252 Concatenate False
# 253 BatchNormalization False
# 254 Activation False
# 255 Conv2D False
# 256 BatchNormalization False
# 257 Activation False
# 258 Conv2D False
# 259 Concatenate False
# 260 BatchNormalization False
# 261 Activation False
# 262 Conv2D False
# 263 BatchNormalization False
# 264 Activation False
# 265 Conv2D False
# 266 Concatenate False
# 267 BatchNormalization False
# 268 Activation False
# 269 Conv2D False
# 270 BatchNormalization False
# 271 Activation False
# 272 Conv2D False
# 273 Concatenate False
# 274 BatchNormalization False
# 275 Activation False
# 276 Conv2D False
# 277 BatchNormalization False
# 278 Activation False
# 279 Conv2D False
# 280 Concatenate False
# 281 BatchNormalization False
# 282 Activation False
# 283 Conv2D False
# 284 BatchNormalization False
# 285 Activation False
# 286 Conv2D False
# 287 Concatenate False
# 288 BatchNormalization False
# 289 Activation False
# 290 Conv2D False
# 291 BatchNormalization False
# 292 Activation False
# 293 Conv2D False
# 294 Concatenate False
# 295 BatchNormalization False
# 296 Activation False
# 297 Conv2D False
# 298 BatchNormalization False
# 299 Activation False
# 300 Conv2D False
# 301 Concatenate False
# 302 BatchNormalization False
# 303 Activation False
# 304 Conv2D False
# 305 BatchNormalization False
# 306 Activation False
# 307 Conv2D False
# 308 Concatenate False
# 309 BatchNormalization False
# 310 Activation False
# 311 Conv2D False
# 312 BatchNormalization False
# 313 Activation False
# 314 Conv2D False
# 315 Concatenate False
# 316 BatchNormalization False
# 317 Activation False
# 318 Conv2D False
# 319 BatchNormalization False
# 320 Activation False
# 321 Conv2D False
# 322 Concatenate False
# 323 BatchNormalization False
# 324 Activation False
# 325 Conv2D False
# 326 BatchNormalization False
# 327 Activation False
# 328 Conv2D False
# 329 Concatenate False
# 330 BatchNormalization False
# 331 Activation False
# 332 Conv2D False
# 333 BatchNormalization False
# 334 Activation False
# 335 Conv2D False
# 336 Concatenate False
# 337 BatchNormalization False
# 338 Activation False
# 339 Conv2D False
# 340 BatchNormalization False
# 341 Activation False
# 342 Conv2D False
# 343 Concatenate False
# 344 BatchNormalization False
# 345 Activation False
# 346 Conv2D False
# 347 BatchNormalization False
# 348 Activation False
# 349 Conv2D False
# 350 Concatenate False
# 351 BatchNormalization False
# 352 Activation False
# 353 Conv2D False
# 354 BatchNormalization False
# 355 Activation False
# 356 Conv2D False
# 357 Concatenate False
# 358 BatchNormalization False
# 359 Activation False
# 360 Conv2D False
# 361 BatchNormalization False
# 362 Activation False
# 363 Conv2D False
# 364 Concatenate False
# 365 BatchNormalization False
# 366 Activation False
# 367 Conv2D False
# 368 BatchNormalization False
# 369 Activation False
# 370 Conv2D False
# 371 Concatenate False
# 372 BatchNormalization False
# 373 Activation False
# 374 Conv2D False
# 375 BatchNormalization False
# 376 Activation False
# 377 Conv2D False
# 378 Concatenate False
# 379 BatchNormalization False
# 380 Activation False
# 381 Conv2D False
# 382 BatchNormalization False
# 383 Activation False
# 384 Conv2D False
# 385 Concatenate False
# 386 BatchNormalization False
# 387 Activation False
# 388 Conv2D False
# 389 BatchNormalization False
# 390 Activation False
# 391 Conv2D False
# 392 Concatenate False
# 393 BatchNormalization False
# 394 Activation False
# 395 Conv2D False
# 396 BatchNormalization False
# 397 Activation False
# 398 Conv2D False
# 399 Concatenate False
# 400 BatchNormalization False
# 401 Activation False
# 402 Conv2D False
# 403 BatchNormalization False
# 404 Activation False
# 405 Conv2D False
# 406 Concatenate False
# 407 BatchNormalization False
# 408 Activation False
# 409 Conv2D False
# 410 BatchNormalization False
# 411 Activation False
# 412 Conv2D False
# 413 Concatenate False
# 414 BatchNormalization False
# 415 Activation False
# 416 Conv2D False
# 417 BatchNormalization False
# 418 Activation False
# 419 Conv2D False
# 420 Concatenate False
# 421 BatchNormalization False
# 422 Activation False
# 423 Conv2D False
# 424 BatchNormalization False
# 425 Activation False
# 426 Conv2D False
# 427 Concatenate False
# 428 BatchNormalization False
# 429 Activation False
# 430 Conv2D False
# 431 BatchNormalization False
# 432 Activation False
# 433 Conv2D False
# 434 Concatenate False
# 435 BatchNormalization False
# 436 Activation False
# 437 Conv2D False
# 438 BatchNormalization False
# 439 Activation False
# 440 Conv2D False
# 441 Concatenate False
# 442 BatchNormalization False
# 443 Activation False
# 444 Conv2D False
# 445 BatchNormalization False
# 446 Activation False
# 447 Conv2D False
# 448 Concatenate False
# 449 BatchNormalization False
# 450 Activation False
# 451 Conv2D False
# 452 BatchNormalization False
# 453 Activation False
# 454 Conv2D False
# 455 Concatenate False
# 456 BatchNormalization False
# 457 Activation False
# 458 Conv2D False
# 459 BatchNormalization False
# 460 Activation False
# 461 Conv2D False
# 462 Concatenate False
# 463 BatchNormalization False
# 464 Activation False
# 465 Conv2D False
# 466 BatchNormalization False
# 467 Activation False
# 468 Conv2D False
# 469 Concatenate False
# 470 BatchNormalization False
# 471 Activation False
# 472 Conv2D False
# 473 BatchNormalization False
# 474 Activation False
# 475 Conv2D False
# 476 Concatenate False
# 477 BatchNormalization False
# 478 Activation False
# 479 Conv2D False
# 480 AveragePooling2D False
# 481 BatchNormalization False
# 482 Activation False
# 483 Conv2D False
# 484 BatchNormalization False
# 485 Activation False
# 486 Conv2D False
# 487 Concatenate False
# 488 BatchNormalization False
# 489 Activation False
# 490 Conv2D False
# 491 BatchNormalization False
# 492 Activation False
# 493 Conv2D False
# 494 Concatenate False
# 495 BatchNormalization False
# 496 Activation False
# 497 Conv2D False
# 498 BatchNormalization False
# 499 Activation False
# 500 Conv2D False
# 501 Concatenate False
# 502 BatchNormalization False
# 503 Activation False
# 504 Conv2D False
# 505 BatchNormalization False
# 506 Activation False
# 507 Conv2D False
# 508 Concatenate False
# 509 BatchNormalization False
# 510 Activation False
# 511 Conv2D False
# 512 BatchNormalization False
# 513 Activation False
# 514 Conv2D False
# 515 Concatenate False
# 516 BatchNormalization False
# 517 Activation False
# 518 Conv2D False
# 519 BatchNormalization False
# 520 Activation False
# 521 Conv2D False
# 522 Concatenate False
# 523 BatchNormalization False
# 524 Activation False
# 525 Conv2D False
# 526 BatchNormalization False
# 527 Activation False
# 528 Conv2D False
# 529 Concatenate False
# 530 BatchNormalization False
# 531 Activation False
# 532 Conv2D False
# 533 BatchNormalization False
# 534 Activation False
# 535 Conv2D False
# 536 Concatenate False
# 537 BatchNormalization False
# 538 Activation False
# 539 Conv2D False
# 540 BatchNormalization False
# 541 Activation False
# 542 Conv2D False
# 543 Concatenate False
# 544 BatchNormalization False
# 545 Activation False
# 546 Conv2D False
# 547 BatchNormalization False
# 548 Activation False
# 549 Conv2D False
# 550 Concatenate False
# 551 BatchNormalization False
# 552 Activation False
# 553 Conv2D False
# 554 BatchNormalization False
# 555 Activation False
# 556 Conv2D False
# 557 Concatenate False
# 558 BatchNormalization False
# 559 Activation False
# 560 Conv2D False
# 561 BatchNormalization False
# 562 Activation False
# 563 Conv2D False
# 564 Concatenate False
# 565 BatchNormalization False
# 566 Activation False
# 567 Conv2D False
# 568 BatchNormalization False
# 569 Activation False
# 570 Conv2D False
# 571 Concatenate False
# 572 BatchNormalization False
# 573 Activation False
# 574 Conv2D False
# 575 BatchNormalization False
# 576 Activation False
# 577 Conv2D False
# 578 Concatenate False
# 579 BatchNormalization False
# 580 Activation False
# 581 Conv2D False
# 582 BatchNormalization False
# 583 Activation False
# 584 Conv2D False
# 585 Concatenate False
# 586 BatchNormalization False
# 587 Activation False
# 588 Conv2D False
# 589 BatchNormalization False
# 590 Activation False
# 591 Conv2D False
# 592 Concatenate False
# 593 BatchNormalization False
# 594 Activation False
# 595 Conv2D False
# 596 BatchNormalization False
# 597 Activation False
# 598 Conv2D False
# 599 Concatenate False
# 600 BatchNormalization False
# 601 Activation False
# 602 Conv2D False
# 603 BatchNormalization False
# 604 Activation False
# 605 Conv2D False
# 606 Concatenate False
# 607 BatchNormalization False
# 608 Activation False
# 609 Conv2D False
# 610 BatchNormalization False
# 611 Activation False
# 612 Conv2D False
# 613 Concatenate False
# 614 BatchNormalization False
# 615 Activation False
# 616 Conv2D False
# 617 BatchNormalization False
# 618 Activation False
# 619 Conv2D False
# 620 Concatenate False
# 621 BatchNormalization False
# 622 Activation False
# 623 Conv2D False
# 624 BatchNormalization False
# 625 Activation False
# 626 Conv2D False
# 627 Concatenate False
# 628 BatchNormalization False
# 629 Activation False
# 630 Conv2D False
# 631 BatchNormalization False
# 632 Activation False
# 633 Conv2D False
# 634 Concatenate False
# 635 BatchNormalization False
# 636 Activation False
# 637 Conv2D False
# 638 BatchNormalization False
# 639 Activation False
# 640 Conv2D False
# 641 Concatenate False
# 642 BatchNormalization False
# 643 Activation False
# 644 Conv2D False
# 645 BatchNormalization False
# 646 Activation False
# 647 Conv2D False
# 648 Concatenate False
# 649 BatchNormalization False
# 650 Activation False
# 651 Conv2D False
# 652 BatchNormalization False
# 653 Activation False
# 654 Conv2D False
# 655 Concatenate False
# 656 BatchNormalization False
# 657 Activation False
# 658 Conv2D False
# 659 BatchNormalization False
# 660 Activation False
# 661 Conv2D False
# 662 Concatenate False
# 663 BatchNormalization False
# 664 Activation False
# 665 Conv2D False
# 666 BatchNormalization False
# 667 Activation False
# 668 Conv2D False
# 669 Concatenate False
# 670 BatchNormalization False
# 671 Activation False
# 672 Conv2D False
# 673 BatchNormalization False
# 674 Activation False
# 675 Conv2D False
# 676 Concatenate False
# 677 BatchNormalization False
# 678 Activation False
# 679 Conv2D False
# 680 BatchNormalization False
# 681 Activation False
# 682 Conv2D False
# 683 Concatenate False
# 684 BatchNormalization False
# 685 Activation False
# 686 Conv2D False
# 687 BatchNormalization False
# 688 Activation False
# 689 Conv2D False
# 690 Concatenate False
# 691 BatchNormalization False
# 692 Activation False
# 693 Conv2D False
# 694 BatchNormalization False
# 695 Activation False
# 696 Conv2D False
# 697 Concatenate False
# 698 BatchNormalization False
# 699 Activation False
# 700 Conv2D False
# 701 BatchNormalization False
# 702 Activation False
# 703 Conv2D False
# 704 Concatenate False
# 705 BatchNormalization False
# 706 Activation False

# %% [markdown]
# **Fine Tuning**

# %%
for layer in model.layers[:451]:
   layer.trainable = False
for layer in model.layers[451:]:
   layer.trainable = True

print('Last block of the conv_base is now trainable')
for i, layer in enumerate(model.layers):
   print(i, layer.name, layer.trainable)
# Out:
# Last block of the conv_base is now trainable
# 0 input_1 False
# 1 zero_padding2d False
# 2 conv1/conv False
# 3 conv1/bn False
# 4 conv1/relu False
# 5 zero_padding2d_1 False
# 6 pool1 False
# 7 conv2_block1_0_bn False
# 8 conv2_block1_0_relu False
# 9 conv2_block1_1_conv False
# 10 conv2_block1_1_bn False
# 11 conv2_block1_1_relu False
# 12 conv2_block1_2_conv False
# 13 conv2_block1_concat False
# 14 conv2_block2_0_bn False
# 15 conv2_block2_0_relu False
# 16 conv2_block2_1_conv False
# 17 conv2_block2_1_bn False
# 18 conv2_block2_1_relu False
# 19 conv2_block2_2_conv False
# 20 conv2_block2_concat False
# 21 conv2_block3_0_bn False
# 22 conv2_block3_0_relu False
# 23 conv2_block3_1_conv False
# 24 conv2_block3_1_bn False
# 25 conv2_block3_1_relu False
# 26 conv2_block3_2_conv False
# 27 conv2_block3_concat False
# 28 conv2_block4_0_bn False
# 29 conv2_block4_0_relu False
# 30 conv2_block4_1_conv False
# 31 conv2_block4_1_bn False
# 32 conv2_block4_1_relu False
# 33 conv2_block4_2_conv False
# 34 conv2_block4_concat False
# 35 conv2_block5_0_bn False
# 36 conv2_block5_0_relu False
# 37 conv2_block5_1_conv False
# 38 conv2_block5_1_bn False
# 39 conv2_block5_1_relu False
# 40 conv2_block5_2_conv False
# 41 conv2_block5_concat False
# 42 conv2_block6_0_bn False
# 43 conv2_block6_0_relu False
# 44 conv2_block6_1_conv False
# 45 conv2_block6_1_bn False
# 46 conv2_block6_1_relu False
# 47 conv2_block6_2_conv False
# 48 conv2_block6_concat False
# 49 pool2_bn False
# 50 pool2_relu False
# 51 pool2_conv False
# 52 pool2_pool False
# 53 conv3_block1_0_bn False
# 54 conv3_block1_0_relu False
# 55 conv3_block1_1_conv False
# 56 conv3_block1_1_bn False
# 57 conv3_block1_1_relu False
# 58 conv3_block1_2_conv False
# 59 conv3_block1_concat False
# 60 conv3_block2_0_bn False
# 61 conv3_block2_0_relu False
# 62 conv3_block2_1_conv False
# 63 conv3_block2_1_bn False
# 64 conv3_block2_1_relu False
# 65 conv3_block2_2_conv False
# 66 conv3_block2_concat False
# 67 conv3_block3_0_bn False
# 68 conv3_block3_0_relu False
# 69 conv3_block3_1_conv False
# 70 conv3_block3_1_bn False
# 71 conv3_block3_1_relu False
# 72 conv3_block3_2_conv False
# 73 conv3_block3_concat False
# 74 conv3_block4_0_bn False
# 75 conv3_block4_0_relu False
# 76 conv3_block4_1_conv False
# 77 conv3_block4_1_bn False
# 78 conv3_block4_1_relu False
# 79 conv3_block4_2_conv False
# 80 conv3_block4_concat False
# 81 conv3_block5_0_bn False
# 82 conv3_block5_0_relu False
# 83 conv3_block5_1_conv False
# 84 conv3_block5_1_bn False
# 85 conv3_block5_1_relu False
# 86 conv3_block5_2_conv False
# 87 conv3_block5_concat False
# 88 conv3_block6_0_bn False
# 89 conv3_block6_0_relu False
# 90 conv3_block6_1_conv False
# 91 conv3_block6_1_bn False
# 92 conv3_block6_1_relu False
# 93 conv3_block6_2_conv False
# 94 conv3_block6_concat False
# 95 conv3_block7_0_bn False
# 96 conv3_block7_0_relu False
# 97 conv3_block7_1_conv False
# 98 conv3_block7_1_bn False
# 99 conv3_block7_1_relu False
# 100 conv3_block7_2_conv False
# 101 conv3_block7_concat False
# 102 conv3_block8_0_bn False
# 103 conv3_block8_0_relu False
# 104 conv3_block8_1_conv False
# 105 conv3_block8_1_bn False
# 106 conv3_block8_1_relu False
# 107 conv3_block8_2_conv False
# 108 conv3_block8_concat False
# 109 conv3_block9_0_bn False
# 110 conv3_block9_0_relu False
# 111 conv3_block9_1_conv False
# 112 conv3_block9_1_bn False
# 113 conv3_block9_1_relu False
# 114 conv3_block9_2_conv False
# 115 conv3_block9_concat False
# 116 conv3_block10_0_bn False
# 117 conv3_block10_0_relu False
# 118 conv3_block10_1_conv False
# 119 conv3_block10_1_bn False
# 120 conv3_block10_1_relu False
# 121 conv3_block10_2_conv False
# 122 conv3_block10_concat False
# 123 conv3_block11_0_bn False
# 124 conv3_block11_0_relu False
# 125 conv3_block11_1_conv False
# 126 conv3_block11_1_bn False
# 127 conv3_block11_1_relu False
# 128 conv3_block11_2_conv False
# 129 conv3_block11_concat False
# 130 conv3_block12_0_bn False
# 131 conv3_block12_0_relu False
# 132 conv3_block12_1_conv False
# 133 conv3_block12_1_bn False
# 134 conv3_block12_1_relu False
# 135 conv3_block12_2_conv False
# 136 conv3_block12_concat False
# 137 pool3_bn False
# 138 pool3_relu False
# 139 pool3_conv False
# 140 pool3_pool False
# 141 conv4_block1_0_bn False
# 142 conv4_block1_0_relu False
# 143 conv4_block1_1_conv False
# 144 conv4_block1_1_bn False
# 145 conv4_block1_1_relu False
# 146 conv4_block1_2_conv False
# 147 conv4_block1_concat False
# 148 conv4_block2_0_bn False
# 149 conv4_block2_0_relu False
# 150 conv4_block2_1_conv False
# 151 conv4_block2_1_bn False
# 152 conv4_block2_1_relu False
# 153 conv4_block2_2_conv False
# 154 conv4_block2_concat False
# 155 conv4_block3_0_bn False
# 156 conv4_block3_0_relu False
# 157 conv4_block3_1_conv False
# 158 conv4_block3_1_bn False
# 159 conv4_block3_1_relu False
# 160 conv4_block3_2_conv False
# 161 conv4_block3_concat False
# 162 conv4_block4_0_bn False
# 163 conv4_block4_0_relu False
# 164 conv4_block4_1_conv False
# 165 conv4_block4_1_bn False
# 166 conv4_block4_1_relu False
# 167 conv4_block4_2_conv False
# 168 conv4_block4_concat False
# 169 conv4_block5_0_bn False
# 170 conv4_block5_0_relu False
# 171 conv4_block5_1_conv False
# 172 conv4_block5_1_bn False
# 173 conv4_block5_1_relu False
# 174 conv4_block5_2_conv False
# 175 conv4_block5_concat False
# 176 conv4_block6_0_bn False
# 177 conv4_block6_0_relu False
# 178 conv4_block6_1_conv False
# 179 conv4_block6_1_bn False
# 180 conv4_block6_1_relu False
# 181 conv4_block6_2_conv False
# 182 conv4_block6_concat False
# 183 conv4_block7_0_bn False
# 184 conv4_block7_0_relu False
# 185 conv4_block7_1_conv False
# 186 conv4_block7_1_bn False
# 187 conv4_block7_1_relu False
# 188 conv4_block7_2_conv False
# 189 conv4_block7_concat False
# 190 conv4_block8_0_bn False
# 191 conv4_block8_0_relu False
# 192 conv4_block8_1_conv False
# 193 conv4_block8_1_bn False
# 194 conv4_block8_1_relu False
# 195 conv4_block8_2_conv False
# 196 conv4_block8_concat False
# 197 conv4_block9_0_bn False
# 198 conv4_block9_0_relu False
# 199 conv4_block9_1_conv False
# 200 conv4_block9_1_bn False
# 201 conv4_block9_1_relu False
# 202 conv4_block9_2_conv False
# 203 conv4_block9_concat False
# 204 conv4_block10_0_bn False
# 205 conv4_block10_0_relu False
# 206 conv4_block10_1_conv False
# 207 conv4_block10_1_bn False
# 208 conv4_block10_1_relu False
# 209 conv4_block10_2_conv False
# 210 conv4_block10_concat False
# 211 conv4_block11_0_bn False
# 212 conv4_block11_0_relu False
# 213 conv4_block11_1_conv False
# 214 conv4_block11_1_bn False
# 215 conv4_block11_1_relu False
# 216 conv4_block11_2_conv False
# 217 conv4_block11_concat False
# 218 conv4_block12_0_bn False
# 219 conv4_block12_0_relu False
# 220 conv4_block12_1_conv False
# 221 conv4_block12_1_bn False
# 222 conv4_block12_1_relu False
# 223 conv4_block12_2_conv False
# 224 conv4_block12_concat False
# 225 conv4_block13_0_bn False
# 226 conv4_block13_0_relu False
# 227 conv4_block13_1_conv False
# 228 conv4_block13_1_bn False
# 229 conv4_block13_1_relu False
# 230 conv4_block13_2_conv False
# 231 conv4_block13_concat False
# 232 conv4_block14_0_bn False
# 233 conv4_block14_0_relu False
# 234 conv4_block14_1_conv False
# 235 conv4_block14_1_bn False
# 236 conv4_block14_1_relu False
# 237 conv4_block14_2_conv False
# 238 conv4_block14_concat False
# 239 conv4_block15_0_bn False
# 240 conv4_block15_0_relu False
# 241 conv4_block15_1_conv False
# 242 conv4_block15_1_bn False
# 243 conv4_block15_1_relu False
# 244 conv4_block15_2_conv False
# 245 conv4_block15_concat False
# 246 conv4_block16_0_bn False
# 247 conv4_block16_0_relu False
# 248 conv4_block16_1_conv False
# 249 conv4_block16_1_bn False
# 250 conv4_block16_1_relu False
# 251 conv4_block16_2_conv False
# 252 conv4_block16_concat False
# 253 conv4_block17_0_bn False
# 254 conv4_block17_0_relu False
# 255 conv4_block17_1_conv False
# 256 conv4_block17_1_bn False
# 257 conv4_block17_1_relu False
# 258 conv4_block17_2_conv False
# 259 conv4_block17_concat False
# 260 conv4_block18_0_bn False
# 261 conv4_block18_0_relu False
# 262 conv4_block18_1_conv False
# 263 conv4_block18_1_bn False
# 264 conv4_block18_1_relu False
# 265 conv4_block18_2_conv False
# 266 conv4_block18_concat False
# 267 conv4_block19_0_bn False
# 268 conv4_block19_0_relu False
# 269 conv4_block19_1_conv False
# 270 conv4_block19_1_bn False
# 271 conv4_block19_1_relu False
# 272 conv4_block19_2_conv False
# 273 conv4_block19_concat False
# 274 conv4_block20_0_bn False
# 275 conv4_block20_0_relu False
# 276 conv4_block20_1_conv False
# 277 conv4_block20_1_bn False
# 278 conv4_block20_1_relu False
# 279 conv4_block20_2_conv False
# 280 conv4_block20_concat False
# 281 conv4_block21_0_bn False
# 282 conv4_block21_0_relu False
# 283 conv4_block21_1_conv False
# 284 conv4_block21_1_bn False
# 285 conv4_block21_1_relu False
# 286 conv4_block21_2_conv False
# 287 conv4_block21_concat False
# 288 conv4_block22_0_bn False
# 289 conv4_block22_0_relu False
# 290 conv4_block22_1_conv False
# 291 conv4_block22_1_bn False
# 292 conv4_block22_1_relu False
# 293 conv4_block22_2_conv False
# 294 conv4_block22_concat False
# 295 conv4_block23_0_bn False
# 296 conv4_block23_0_relu False
# 297 conv4_block23_1_conv False
# 298 conv4_block23_1_bn False
# 299 conv4_block23_1_relu False
# 300 conv4_block23_2_conv False
# 301 conv4_block23_concat False
# 302 conv4_block24_0_bn False
# 303 conv4_block24_0_relu False
# 304 conv4_block24_1_conv False
# 305 conv4_block24_1_bn False
# 306 conv4_block24_1_relu False
# 307 conv4_block24_2_conv False
# 308 conv4_block24_concat False
# 309 conv4_block25_0_bn False
# 310 conv4_block25_0_relu False
# 311 conv4_block25_1_conv False
# 312 conv4_block25_1_bn False
# 313 conv4_block25_1_relu False
# 314 conv4_block25_2_conv False
# 315 conv4_block25_concat False
# 316 conv4_block26_0_bn False
# 317 conv4_block26_0_relu False
# 318 conv4_block26_1_conv False
# 319 conv4_block26_1_bn False
# 320 conv4_block26_1_relu False
# 321 conv4_block26_2_conv False
# 322 conv4_block26_concat False
# 323 conv4_block27_0_bn False
# 324 conv4_block27_0_relu False
# 325 conv4_block27_1_conv False
# 326 conv4_block27_1_bn False
# 327 conv4_block27_1_relu False
# 328 conv4_block27_2_conv False
# 329 conv4_block27_concat False
# 330 conv4_block28_0_bn False
# 331 conv4_block28_0_relu False
# 332 conv4_block28_1_conv False
# 333 conv4_block28_1_bn False
# 334 conv4_block28_1_relu False
# 335 conv4_block28_2_conv False
# 336 conv4_block28_concat False
# 337 conv4_block29_0_bn False
# 338 conv4_block29_0_relu False
# 339 conv4_block29_1_conv False
# 340 conv4_block29_1_bn False
# 341 conv4_block29_1_relu False
# 342 conv4_block29_2_conv False
# 343 conv4_block29_concat False
# 344 conv4_block30_0_bn False
# 345 conv4_block30_0_relu False
# 346 conv4_block30_1_conv False
# 347 conv4_block30_1_bn False
# 348 conv4_block30_1_relu False
# 349 conv4_block30_2_conv False
# 350 conv4_block30_concat False
# 351 conv4_block31_0_bn False
# 352 conv4_block31_0_relu False
# 353 conv4_block31_1_conv False
# 354 conv4_block31_1_bn False
# 355 conv4_block31_1_relu False
# 356 conv4_block31_2_conv False
# 357 conv4_block31_concat False
# 358 conv4_block32_0_bn False
# 359 conv4_block32_0_relu False
# 360 conv4_block32_1_conv False
# 361 conv4_block32_1_bn False
# 362 conv4_block32_1_relu False
# 363 conv4_block32_2_conv False
# 364 conv4_block32_concat False
# 365 conv4_block33_0_bn False
# 366 conv4_block33_0_relu False
# 367 conv4_block33_1_conv False
# 368 conv4_block33_1_bn False
# 369 conv4_block33_1_relu False
# 370 conv4_block33_2_conv False
# 371 conv4_block33_concat False
# 372 conv4_block34_0_bn False
# 373 conv4_block34_0_relu False
# 374 conv4_block34_1_conv False
# 375 conv4_block34_1_bn False
# 376 conv4_block34_1_relu False
# 377 conv4_block34_2_conv False
# 378 conv4_block34_concat False
# 379 conv4_block35_0_bn False
# 380 conv4_block35_0_relu False
# 381 conv4_block35_1_conv False
# 382 conv4_block35_1_bn False
# 383 conv4_block35_1_relu False
# 384 conv4_block35_2_conv False
# 385 conv4_block35_concat False
# 386 conv4_block36_0_bn False
# 387 conv4_block36_0_relu False
# 388 conv4_block36_1_conv False
# 389 conv4_block36_1_bn False
# 390 conv4_block36_1_relu False
# 391 conv4_block36_2_conv False
# 392 conv4_block36_concat False
# 393 conv4_block37_0_bn False
# 394 conv4_block37_0_relu False
# 395 conv4_block37_1_conv False
# 396 conv4_block37_1_bn False
# 397 conv4_block37_1_relu False
# 398 conv4_block37_2_conv False
# 399 conv4_block37_concat False
# 400 conv4_block38_0_bn False
# 401 conv4_block38_0_relu False
# 402 conv4_block38_1_conv False
# 403 conv4_block38_1_bn False
# 404 conv4_block38_1_relu False
# 405 conv4_block38_2_conv False
# 406 conv4_block38_concat False
# 407 conv4_block39_0_bn False
# 408 conv4_block39_0_relu False
# 409 conv4_block39_1_conv False
# 410 conv4_block39_1_bn False
# 411 conv4_block39_1_relu False
# 412 conv4_block39_2_conv False
# 413 conv4_block39_concat False
# 414 conv4_block40_0_bn False
# 415 conv4_block40_0_relu False
# 416 conv4_block40_1_conv False
# 417 conv4_block40_1_bn False
# 418 conv4_block40_1_relu False
# 419 conv4_block40_2_conv False
# 420 conv4_block40_concat False
# 421 conv4_block41_0_bn False
# 422 conv4_block41_0_relu False
# 423 conv4_block41_1_conv False
# 424 conv4_block41_1_bn False
# 425 conv4_block41_1_relu False
# 426 conv4_block41_2_conv False
# 427 conv4_block41_concat False
# 428 conv4_block42_0_bn False
# 429 conv4_block42_0_relu False
# 430 conv4_block42_1_conv False
# 431 conv4_block42_1_bn False
# 432 conv4_block42_1_relu False
# 433 conv4_block42_2_conv False
# 434 conv4_block42_concat False
# 435 conv4_block43_0_bn False
# 436 conv4_block43_0_relu False
# 437 conv4_block43_1_conv False
# 438 conv4_block43_1_bn False
# 439 conv4_block43_1_relu False
# 440 conv4_block43_2_conv False
# 441 conv4_block43_concat False
# 442 conv4_block44_0_bn False
# 443 conv4_block44_0_relu False
# 444 conv4_block44_1_conv False
# 445 conv4_block44_1_bn False
# 446 conv4_block44_1_relu False
# 447 conv4_block44_2_conv False
# 448 conv4_block44_concat False
# 449 conv4_block45_0_bn False
# 450 conv4_block45_0_relu False
# 451 conv4_block45_1_conv True
# 452 conv4_block45_1_bn True
# 453 conv4_block45_1_relu True
# 454 conv4_block45_2_conv True
# 455 conv4_block45_concat True
# 456 conv4_block46_0_bn True
# 457 conv4_block46_0_relu True
# 458 conv4_block46_1_conv True
# 459 conv4_block46_1_bn True
# 460 conv4_block46_1_relu True
# 461 conv4_block46_2_conv True
# 462 conv4_block46_concat True
# 463 conv4_block47_0_bn True
# 464 conv4_block47_0_relu True
# 465 conv4_block47_1_conv True
# 466 conv4_block47_1_bn True
# 467 conv4_block47_1_relu True
# 468 conv4_block47_2_conv True
# 469 conv4_block47_concat True
# 470 conv4_block48_0_bn True
# 471 conv4_block48_0_relu True
# 472 conv4_block48_1_conv True
# 473 conv4_block48_1_bn True
# 474 conv4_block48_1_relu True
# 475 conv4_block48_2_conv True
# 476 conv4_block48_concat True
# 477 pool4_bn True
# 478 pool4_relu True
# 479 pool4_conv True
# 480 pool4_pool True
# 481 conv5_block1_0_bn True
# 482 conv5_block1_0_relu True
# 483 conv5_block1_1_conv True
# 484 conv5_block1_1_bn True
# 485 conv5_block1_1_relu True
# 486 conv5_block1_2_conv True
# 487 conv5_block1_concat True
# 488 conv5_block2_0_bn True
# 489 conv5_block2_0_relu True
# 490 conv5_block2_1_conv True
# 491 conv5_block2_1_bn True
# 492 conv5_block2_1_relu True
# 493 conv5_block2_2_conv True
# 494 conv5_block2_concat True
# 495 conv5_block3_0_bn True
# 496 conv5_block3_0_relu True
# 497 conv5_block3_1_conv True
# 498 conv5_block3_1_bn True
# 499 conv5_block3_1_relu True
# 500 conv5_block3_2_conv True
# 501 conv5_block3_concat True
# 502 conv5_block4_0_bn True
# 503 conv5_block4_0_relu True
# 504 conv5_block4_1_conv True
# 505 conv5_block4_1_bn True
# 506 conv5_block4_1_relu True
# 507 conv5_block4_2_conv True
# 508 conv5_block4_concat True
# 509 conv5_block5_0_bn True
# 510 conv5_block5_0_relu True
# 511 conv5_block5_1_conv True
# 512 conv5_block5_1_bn True
# 513 conv5_block5_1_relu True
# 514 conv5_block5_2_conv True
# 515 conv5_block5_concat True
# 516 conv5_block6_0_bn True
# 517 conv5_block6_0_relu True
# 518 conv5_block6_1_conv True
# 519 conv5_block6_1_bn True
# 520 conv5_block6_1_relu True
# 521 conv5_block6_2_conv True
# 522 conv5_block6_concat True
# 523 conv5_block7_0_bn True
# 524 conv5_block7_0_relu True
# 525 conv5_block7_1_conv True
# 526 conv5_block7_1_bn True
# 527 conv5_block7_1_relu True
# 528 conv5_block7_2_conv True
# 529 conv5_block7_concat True
# 530 conv5_block8_0_bn True
# 531 conv5_block8_0_relu True
# 532 conv5_block8_1_conv True
# 533 conv5_block8_1_bn True
# 534 conv5_block8_1_relu True
# 535 conv5_block8_2_conv True
# 536 conv5_block8_concat True
# 537 conv5_block9_0_bn True
# 538 conv5_block9_0_relu True
# 539 conv5_block9_1_conv True
# 540 conv5_block9_1_bn True
# 541 conv5_block9_1_relu True
# 542 conv5_block9_2_conv True
# 543 conv5_block9_concat True
# 544 conv5_block10_0_bn True
# 545 conv5_block10_0_relu True
# 546 conv5_block10_1_conv True
# 547 conv5_block10_1_bn True
# 548 conv5_block10_1_relu True
# 549 conv5_block10_2_conv True
# 550 conv5_block10_concat True
# 551 conv5_block11_0_bn True
# 552 conv5_block11_0_relu True
# 553 conv5_block11_1_conv True
# 554 conv5_block11_1_bn True
# 555 conv5_block11_1_relu True
# 556 conv5_block11_2_conv True
# 557 conv5_block11_concat True
# 558 conv5_block12_0_bn True
# 559 conv5_block12_0_relu True
# 560 conv5_block12_1_conv True
# 561 conv5_block12_1_bn True
# 562 conv5_block12_1_relu True
# 563 conv5_block12_2_conv True
# 564 conv5_block12_concat True
# 565 conv5_block13_0_bn True
# 566 conv5_block13_0_relu True
# 567 conv5_block13_1_conv True
# 568 conv5_block13_1_bn True
# 569 conv5_block13_1_relu True
# 570 conv5_block13_2_conv True
# 571 conv5_block13_concat True
# 572 conv5_block14_0_bn True
# 573 conv5_block14_0_relu True
# 574 conv5_block14_1_conv True
# 575 conv5_block14_1_bn True
# 576 conv5_block14_1_relu True
# 577 conv5_block14_2_conv True
# 578 conv5_block14_concat True
# 579 conv5_block15_0_bn True
# 580 conv5_block15_0_relu True
# 581 conv5_block15_1_conv True
# 582 conv5_block15_1_bn True
# 583 conv5_block15_1_relu True
# 584 conv5_block15_2_conv True
# 585 conv5_block15_concat True
# 586 conv5_block16_0_bn True
# 587 conv5_block16_0_relu True
# 588 conv5_block16_1_conv True
# 589 conv5_block16_1_bn True
# 590 conv5_block16_1_relu True
# 591 conv5_block16_2_conv True
# 592 conv5_block16_concat True
# 593 conv5_block17_0_bn True
# 594 conv5_block17_0_relu True
# 595 conv5_block17_1_conv True
# 596 conv5_block17_1_bn True
# 597 conv5_block17_1_relu True
# 598 conv5_block17_2_conv True
# 599 conv5_block17_concat True
# 600 conv5_block18_0_bn True
# 601 conv5_block18_0_relu True
# 602 conv5_block18_1_conv True
# 603 conv5_block18_1_bn True
# 604 conv5_block18_1_relu True
# 605 conv5_block18_2_conv True
# 606 conv5_block18_concat True
# 607 conv5_block19_0_bn True
# 608 conv5_block19_0_relu True
# 609 conv5_block19_1_conv True
# 610 conv5_block19_1_bn True
# 611 conv5_block19_1_relu True
# 612 conv5_block19_2_conv True
# 613 conv5_block19_concat True
# 614 conv5_block20_0_bn True
# 615 conv5_block20_0_relu True
# 616 conv5_block20_1_conv True
# 617 conv5_block20_1_bn True
# 618 conv5_block20_1_relu True
# 619 conv5_block20_2_conv True
# 620 conv5_block20_concat True
# 621 conv5_block21_0_bn True
# 622 conv5_block21_0_relu True
# 623 conv5_block21_1_conv True
# 624 conv5_block21_1_bn True
# 625 conv5_block21_1_relu True
# 626 conv5_block21_2_conv True
# 627 conv5_block21_concat True
# 628 conv5_block22_0_bn True
# 629 conv5_block22_0_relu True
# 630 conv5_block22_1_conv True
# 631 conv5_block22_1_bn True
# 632 conv5_block22_1_relu True
# 633 conv5_block22_2_conv True
# 634 conv5_block22_concat True
# 635 conv5_block23_0_bn True
# 636 conv5_block23_0_relu True
# 637 conv5_block23_1_conv True
# 638 conv5_block23_1_bn True
# 639 conv5_block23_1_relu True
# 640 conv5_block23_2_conv True
# 641 conv5_block23_concat True
# 642 conv5_block24_0_bn True
# 643 conv5_block24_0_relu True
# 644 conv5_block24_1_conv True
# 645 conv5_block24_1_bn True
# 646 conv5_block24_1_relu True
# 647 conv5_block24_2_conv True
# 648 conv5_block24_concat True
# 649 conv5_block25_0_bn True
# 650 conv5_block25_0_relu True
# 651 conv5_block25_1_conv True
# 652 conv5_block25_1_bn True
# 653 conv5_block25_1_relu True
# 654 conv5_block25_2_conv True
# 655 conv5_block25_concat True
# 656 conv5_block26_0_bn True
# 657 conv5_block26_0_relu True
# 658 conv5_block26_1_conv True
# 659 conv5_block26_1_bn True
# 660 conv5_block26_1_relu True
# 661 conv5_block26_2_conv True
# 662 conv5_block26_concat True
# 663 conv5_block27_0_bn True
# 664 conv5_block27_0_relu True
# 665 conv5_block27_1_conv True
# 666 conv5_block27_1_bn True
# 667 conv5_block27_1_relu True
# 668 conv5_block27_2_conv True
# 669 conv5_block27_concat True
# 670 conv5_block28_0_bn True
# 671 conv5_block28_0_relu True
# 672 conv5_block28_1_conv True
# 673 conv5_block28_1_bn True
# 674 conv5_block28_1_relu True
# 675 conv5_block28_2_conv True
# 676 conv5_block28_concat True
# 677 conv5_block29_0_bn True
# 678 conv5_block29_0_relu True
# 679 conv5_block29_1_conv True
# 680 conv5_block29_1_bn True
# 681 conv5_block29_1_relu True
# 682 conv5_block29_2_conv True
# 683 conv5_block29_concat True
# 684 conv5_block30_0_bn True
# 685 conv5_block30_0_relu True
# 686 conv5_block30_1_conv True
# 687 conv5_block30_1_bn True
# 688 conv5_block30_1_relu True
# 689 conv5_block30_2_conv True
# 690 conv5_block30_concat True
# 691 conv5_block31_0_bn True
# 692 conv5_block31_0_relu True
# 693 conv5_block31_1_conv True
# 694 conv5_block31_1_bn True
# 695 conv5_block31_1_relu True
# 696 conv5_block31_2_conv True
# 697 conv5_block31_concat True
# 698 conv5_block32_0_bn True
# 699 conv5_block32_0_relu True
# 700 conv5_block32_1_conv True
# 701 conv5_block32_1_bn True
# 702 conv5_block32_1_relu True
# 703 conv5_block32_2_conv True
# 704 conv5_block32_concat True
# 705 bn True
# 706 relu True

# %%
def lw(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed on top of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024, activation='relu',kernel_regularizer=l2(0.001))(top_model) 
    top_model = Dropout(0.6)(top_model) 
    top_model = Dense(num_classes, activation='softmax')(top_model)
    return top_model

# %%
from keras.models import Model
FC_Head = lw(model, NUM_CLASSES)
model = Model(inputs = model.input, outputs = FC_Head)

# %% [markdown]
# # Training

# %%
from tensorflow.keras.callbacks import LearningRateScheduler


def scheduler(epoch, lr):
     if epoch < 5:
         return .0009
     else:
        return .0009

lr_scheduler = LearningRateScheduler(scheduler)

# %%
if not os.path.exists("Results"):
    os.makedirs("Results")
if not os.path.exists("Model"):
    os.makedirs("Model") 
csv_logger_path = os.path.join("Results", f"{model_name}_results.csv")
model_checkpoint_path = os.path.join("Model", f"{model_name}_Model.hdf5")

# %% [markdown]
# **CheckPoints**

# %%
csv_logger = CSVLogger(csv_logger_path)
early_stopping = EarlyStopping(monitor='val_loss', patience=patience)
check = ModelCheckpoint(model_checkpoint_path, verbose=1, save_best_only=True)
progbar_logger = ProgbarLogger()

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])
history = model.fit(train_generator,
                    epochs=EPOCHS, 
                    batch_size=batch_size,
                    validation_data=validation_generator,
                    verbose = 1,
                    callbacks = [early_stopping,lr_scheduler,check,csv_logger],
                    initial_epoch=0)
# Out:
# Epoch 1/25
# 314/314 [==============================] - ETA: 0s - loss: 0.9077 - accuracy: 0.8830
# Epoch 1: val_loss improved from inf to 0.41907, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 76s 186ms/step - loss: 0.9077 - accuracy: 0.8830 - val_loss: 0.4191 - val_accuracy: 0.9871 - lr: 9.0000e-04
# Epoch 2/25
# 314/314 [==============================] - ETA: 0s - loss: 0.4900 - accuracy: 0.9560
# Epoch 2: val_loss improved from 0.41907 to 0.38162, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 114ms/step - loss: 0.4900 - accuracy: 0.9560 - val_loss: 0.3816 - val_accuracy: 0.9655 - lr: 9.0000e-04
# Epoch 3/25
# 314/314 [==============================] - ETA: 0s - loss: 0.3586 - accuracy: 0.9713
# Epoch 3: val_loss improved from 0.38162 to 0.35856, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 114ms/step - loss: 0.3586 - accuracy: 0.9713 - val_loss: 0.3586 - val_accuracy: 0.9720 - lr: 9.0000e-04
# Epoch 4/25
# 314/314 [==============================] - ETA: 0s - loss: 0.3258 - accuracy: 0.9729
# Epoch 4: val_loss improved from 0.35856 to 0.21871, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 114ms/step - loss: 0.3258 - accuracy: 0.9729 - val_loss: 0.2187 - val_accuracy: 0.9914 - lr: 9.0000e-04
# Epoch 5/25
# 314/314 [==============================] - ETA: 0s - loss: 0.3217 - accuracy: 0.9758
# Epoch 5: val_loss did not improve from 0.21871
# 314/314 [==============================] - 35s 110ms/step - loss: 0.3217 - accuracy: 0.9758 - val_loss: 0.3490 - val_accuracy: 0.9634 - lr: 9.0000e-04
# Epoch 6/25
# 314/314 [==============================] - ETA: 0s - loss: 0.2429 - accuracy: 0.9809
# Epoch 6: val_loss did not improve from 0.21871
# 314/314 [==============================] - 35s 111ms/step - loss: 0.2429 - accuracy: 0.9809 - val_loss: 0.2518 - val_accuracy: 0.9871 - lr: 9.0000e-04
# Epoch 7/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1851 - accuracy: 0.9885
# Epoch 7: val_loss did not improve from 0.21871
# 314/314 [==============================] - 35s 111ms/step - loss: 0.1851 - accuracy: 0.9885 - val_loss: 0.2412 - val_accuracy: 0.9828 - lr: 9.0000e-04
# Epoch 8/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1228 - accuracy: 0.9949
# Epoch 8: val_loss improved from 0.21871 to 0.15988, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 115ms/step - loss: 0.1228 - accuracy: 0.9949 - val_loss: 0.1599 - val_accuracy: 0.9806 - lr: 9.0000e-04
# Epoch 9/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1157 - accuracy: 0.9923
# Epoch 9: val_loss improved from 0.15988 to 0.14667, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 114ms/step - loss: 0.1157 - accuracy: 0.9923 - val_loss: 0.1467 - val_accuracy: 0.9741 - lr: 9.0000e-04
# Epoch 10/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1690 - accuracy: 0.9844
# Epoch 10: val_loss did not improve from 0.14667
# 314/314 [==============================] - 35s 111ms/step - loss: 0.1690 - accuracy: 0.9844 - val_loss: 0.3215 - val_accuracy: 0.9655 - lr: 9.0000e-04
# Epoch 11/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1874 - accuracy: 0.9860
# Epoch 11: val_loss did not improve from 0.14667
# 314/314 [==============================] - 35s 110ms/step - loss: 0.1874 - accuracy: 0.9860 - val_loss: 0.4400 - val_accuracy: 0.9698 - lr: 9.0000e-04
# Epoch 12/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1607 - accuracy: 0.9895
# Epoch 12: val_loss did not improve from 0.14667
# 314/314 [==============================] - 34s 110ms/step - loss: 0.1607 - accuracy: 0.9895 - val_loss: 0.1837 - val_accuracy: 0.9871 - lr: 9.0000e-04
# Epoch 13/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1298 - accuracy: 0.9923
# Epoch 13: val_loss improved from 0.14667 to 0.13401, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 114ms/step - loss: 0.1298 - accuracy: 0.9923 - val_loss: 0.1340 - val_accuracy: 0.9914 - lr: 9.0000e-04
# Epoch 14/25
# 314/314 [==============================] - ETA: 0s - loss: 0.0924 - accuracy: 0.9955
# Epoch 14: val_loss improved from 0.13401 to 0.07658, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 35s 113ms/step - loss: 0.0924 - accuracy: 0.9955 - val_loss: 0.0766 - val_accuracy: 0.9935 - lr: 9.0000e-04
# Epoch 15/25
# 314/314 [==============================] - ETA: 0s - loss: 0.0729 - accuracy: 0.9943
# Epoch 15: val_loss improved from 0.07658 to 0.07488, saving model to Model\densenet201_Model.hdf5
# 314/314 [==============================] - 36s 113ms/step - loss: 0.0729 - accuracy: 0.9943 - val_loss: 0.0749 - val_accuracy: 0.9892 - lr: 9.0000e-04
# Epoch 16/25
# 314/314 [==============================] - ETA: 0s - loss: 0.0704 - accuracy: 0.9949
# Epoch 16: val_loss did not improve from 0.07488
# 314/314 [==============================] - 35s 111ms/step - loss: 0.0704 - accuracy: 0.9949 - val_loss: 0.0757 - val_accuracy: 0.9871 - lr: 9.0000e-04
# Epoch 17/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1042 - accuracy: 0.9898
# Epoch 17: val_loss did not improve from 0.07488
# 314/314 [==============================] - 35s 111ms/step - loss: 0.1042 - accuracy: 0.9898 - val_loss: 0.1871 - val_accuracy: 0.9763 - lr: 9.0000e-04
# Epoch 18/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1144 - accuracy: 0.9911
# Epoch 18: val_loss did not improve from 0.07488
# 314/314 [==============================] - 35s 110ms/step - loss: 0.1144 - accuracy: 0.9911 - val_loss: 0.1382 - val_accuracy: 0.9828 - lr: 9.0000e-04
# Epoch 19/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1971 - accuracy: 0.9844
# Epoch 19: val_loss did not improve from 0.07488
# 314/314 [==============================] - 35s 111ms/step - loss: 0.1971 - accuracy: 0.9844 - val_loss: 0.1521 - val_accuracy: 0.9957 - lr: 9.0000e-04
# Epoch 20/25
# 314/314 [==============================] - ETA: 0s - loss: 0.1469 - accuracy: 0.9904
# Epoch 20: val_loss did not improve from 0.07488
# 314/314 [==============================] - 35s 111ms/step - loss: 0.1469 - accuracy: 0.9904 - val_loss: 0.1904 - val_accuracy: 0.9806 - lr: 9.0000e-04

# %% [markdown]
# **saving models**

# %%
import pickle

pickle_path_json = os.path.join("Results", f"{model_name}_model_architecture.json")
pickle_model_path = os.path.join("Model", f"{model_name}_model_pickle.pkl")

model_architecture = model.to_json()
with open(pickle_path_json, 'w') as f:
    f.write(model_architecture)

with open(pickle_model_path, 'wb') as f:
    pickle.dump(model, f)
# Out:
# INFO:tensorflow:Assets written to: ram://068cf349-5fbb-4e3a-8610-cf45f9f5814d/assets

# %%
model.save(f'{model_name}_.h5')

# %%
model = tf.keras.models.load_model(f'{model_name}_.h5')

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

# %% [markdown]
# # Result

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(acc))

# %%
score = model.evaluate(test_generator ,verbose=1)
print('Test Loss:', score[0])
print('Test accuracy:', score[1]*100)
# Out:
# 40/40 [==============================] - 5s 63ms/step - loss: 0.1289 - accuracy: 0.9950
# Test Loss: 0.128936305642128
# Test accuracy: 99.50000047683716
